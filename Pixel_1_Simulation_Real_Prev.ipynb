# %% [markdown]
# <a href="https://colab.research.google.com/github/JM3927/ARCADE-Pixel-1/blob/main/Pixel_1_Simulation_Real_Prev.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Getting Started - RocketPy in Colab

# %% [markdown]
# We start by setting up our environment. To run this notebook, we will need:
#
# - RocketPy
# - Data files (we will download RocketPy's data from github)
#
# Therefore, let's run the following lines of code:

# %%
# !pip install rocketpy
# Out:
# Collecting rocketpy
#   Downloading rocketpy-1.11.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.12/dist-packages (from rocketpy) (2.0.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.12/dist-packages (from rocketpy) (1.16.3)
# Requirement already satisfied: matplotlib>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from rocketpy) (3.10.0)
# Collecting netCDF4>=1.6.4 (from rocketpy)
#   Downloading netcdf4-1.7.4-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from rocketpy) (2.32.4)
# Requirement already satisfied: pytz in /usr/local/lib/python3.12/dist-packages (from rocketpy) (2025.2)
# Collecting simplekml (from rocketpy)
#   Downloading simplekml-1.3.6.tar.gz (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from rocketpy) (0.3.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->rocketpy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->rocketpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->rocketpy) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->rocketpy) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->rocketpy) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->rocketpy) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->rocketpy) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->rocketpy) (2.9.0.post0)
# Collecting cftime (from netCDF4>=1.6.4->rocketpy)
#   Downloading cftime-1.6.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from netCDF4>=1.6.4->rocketpy) (2026.2.25)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->rocketpy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->rocketpy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->rocketpy) (2.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.9.0->rocketpy) (1.17.0)
# Downloading rocketpy-1.11.0-py3-none-any.whl (382 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 382.2/382.2 kB 9.8 MB/s eta 0:00:00
# Downloading netcdf4-1.7.4-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (10.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 64.0 MB/s eta 0:00:00
# Downloading cftime-1.6.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 56.0 MB/s eta 0:00:00
# Building wheels for collected packages: simplekml
#   Building wheel for simplekml (setup.py) ... done
#   Created wheel for simplekml: filename=simplekml-1.3.6-py3-none-any.whl size=65860 sha256=7ae88c3699830fb30afd8c474640b7efe628b869a35ab1c8c6b244657199d4fb
#   Stored in directory: /root/.cache/pip/wheels/83/ee/f2/65cecfd948f1429ead035fd6d56bc6bd6574a636ddc4d65cbd
# Successfully built simplekml
# Installing collected packages: simplekml, cftime, netCDF4, rocketpy
# Successfully installed cftime-1.6.5 netCDF4-1.7.4 rocketpy-1.11.0 simplekml-1.3.6

# %% [markdown]
# Now we can start!
#
# Here we go through a simplified rocket trajectory simulation to get you started. Let's start by importing the rocketpy module.

# %%
from rocketpy import Environment, Flight, Rocket, SolidMotor

# %% [markdown]
# It is recommended to run the following line to make matplotlib plots which will be shown later interactive and higher quality.

# %%
# %config InlineBackend.figure_formats = ['svg']
# %matplotlib inline

# %% [markdown]
# ## Setting Up a Simulation

# %% [markdown]
# ### Creating an Environment for Spaceport America

# %% [markdown]
# The `Environment` class is used to define the atmosphere, the winds, and the gravity models.
#
# You can find more information about the `Environment` class in the [Environment Class Usage Docs](https://docs.rocketpy.org/en/latest/notebooks/environment/environment_class_usage.html).

# %%
env = Environment(latitude=41.77539290058019, longitude=-86.57246683558242, elevation=692)

# %% [markdown]
# To get weather data from the GFS forecast, available online, we run the following lines.
#
# First, we set tomorrow's date.

# %%
import datetime
from datetime import date

my_date = date(2025, 3, 6) # Date as requested
flight_date = datetime.date.today() + datetime.timedelta(days=2)

env.set_atmospheric_model(type="standard_atmosphere")

env.set_date(
    (flight_date.year, flight_date.month, flight_date.day, 14)
)  # Hour given in UTC time

# %% [markdown]
# Then, we tell env to use a GFS forecast to get the atmospheric conditions for flight.
#
# Don't mind the warning, it just means that not all variables, such as wind speed or atmospheric temperature, are available at all altitudes given by the forecast.

# %%
# Doesn't work
env.set_atmospheric_model(type="windy_atmosphere", file="GFS")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_862/3144004204.py in <cell line: 0>()
#       1 # Doesn't work
# ----> 2 env.set_atmospheric_model(type="windy_atmosphere", file="GFS")
#
# /usr/local/lib/python3.12/dist-packages/rocketpy/environment/environment.py in set_atmospheric_model(self, type, file, dictionary, pressure, temperature, wind_u, wind_v)
#    1302                 self.process_ensemble(dataset, dictionary)
#    1303         else:  # pragma: no cover
# -> 1304             raise ValueError(f"Unknown model type '{type}'.")
#    1305
#    1306         if type not in ["ensemble"]:
#
# ValueError: Unknown model type 'windy_atmosphere'.

# %% [markdown]
# We can see what the weather will look like by calling the info method!

# %%
env.info()
# Out:
# Gravity Details
#
# Acceleration of gravity at surface level:    9.8012 m/s²
# Acceleration of gravity at  80.000 km (ASL): 9.5610 m/s²
#
#
# Launch Site Details
#
# Launch Date: 2026-03-11 14:00:00 UTC
# Launch Site Latitude: 41.77539°
# Launch Site Longitude: -86.57247°
# Reference Datum: SIRGAS2000
# Launch Site UTM coordinates: 36799.62 W    4639870.44 N
# Launch Site UTM zone: 17T
# Launch Site Surface Elevation: 692.0 m
#
#
# Atmospheric Model Details
#
# Atmospheric Model Type: standard_atmosphere
# standard_atmosphere Maximum Height: 80.000 km
#
# Surface Atmospheric Conditions
#
# Surface Wind Speed: 0.00 m/s
# Surface Wind Direction: 0.00°
# Surface Wind Heading: 0.00°
# Surface Pressure: 932.94 hPa
# Surface Temperature: 283.66 K
# Surface Air Density: 1.146 kg/m³
# Surface Speed of Sound: 337.45 m/s
#
#
# Earth Model Details
#
# Earth Radius at Launch site: 6368.69 km
# Semi-major Axis: 6378.14 km
# Semi-minor Axis: 6356.75 km
# Flattening: 0.0034
#
#
# Atmospheric Model Plots

# %% [markdown]
# ### Creating a Motor
#
# A solid rocket motor is used in this case. To create a motor, the SolidMotor class is used and the required arguments are given.
#
# The SolidMotor class requires the user to have a thrust curve ready. This can come either from a .eng file for a commercial motor, such as below, or a .csv file from a static test measurement.
#
# Besides the thrust curve, other parameters such as grain properties and nozzle dimensions must also be given.
#
# See [Solid Motor Class Usage Docs](https://docs.rocketpy.org/en/latest/user/motors/solidmotor.html) for more information.

# %%
Aerotech_K1103X = SolidMotor(
    thrust_source="/content/AeroTech_K1103X.eng",  # your thrust curve file

    # Physical & inertial
    dry_mass=1.459 - 0.830,     # Total – propellant (kg)
    dry_inertia=(0.003, 0.003, 0.0001),

    # Geometry
    nozzle_radius=5.5 / 1000,    # approx from designation (m)
    throat_radius=11 / 1000,    # approx (m)
    grain_number=5,
    grain_density=1815,         # typical APCP density (kg/m3)
    grain_outer_radius=27 / 1000,     # outer radius ~27 mm (fits 54 mm motor)
    grain_initial_inner_radius=15 / 1000,
    grain_initial_height=35 / 1000,
    grain_separation=3 / 1000,
    grains_center_of_mass_position=0.20,  # approximate position (fraction of length)
    center_of_dry_mass_position=0.20,     # approximate (adjust with CAD if needed)

    # Timing
    burn_time=1.6,                 # from certified data

    # Orientation
    coordinate_system_orientation="nozzle_to_combustion_chamber",
    nozzle_position=0,             # bottom of motor
)

# %% [markdown]
# **Pay special attention to *position* related parameters:**
# More details on [Positions and Coordinate Systems](https://docs.rocketpy.org/en/latest/user/positions.html)

# %% [markdown]
# To see what our thrust curve looks like, along with other import properties, we invoke the info method yet again. You may try the all_info method if you want more information all at once!

# %%
Aerotech_K1103X.info()
# Out:
# Nozzle Details
# Nozzle Radius: 0.0055 m
# Nozzle Throat Radius: 0.011 m
#
# Grain Details
# Number of Grains: 5
# Grain Spacing: 0.003 m
# Grain Density: 1815 kg/m3
# Grain Outer Radius: 0.027 m
# Grain Inner Radius: 0.015 m
# Grain Height: 0.035 m
# Grain Volume: 0.000 m3
# Grain Mass: 0.101 kg
#
# Motor Details
# Total Burning Time: 1.6 s
# Total Propellant Mass: 0.503 kg
# Structural Mass Ratio: 0.556
# Average Propellant Exhaust Velocity: 3581.092 m/s
# Average Thrust: 1125.617 N
# Maximum Thrust: 1619.8 N at 0.028 s after ignition.
# Total Impulse: 1800.987 Ns

# %% [markdown]
# ### Creating a Rocket

# %% [markdown]
# A rocket is composed of several components. Namely, we must have a motor (good thing we have the Pro75M1670 ready), a couple of aerodynamic surfaces (nose cone, fins and tail) and parachutes (if we are not launching a missile).
#
# You can find more information about the `Rocket` class in the [Rocket Class Usage Docs](https://docs.rocketpy.org/en/latest/user/rocket.html).
#
# Let's start by initializing our rocket, named Calisto, entering inertia properties, some dimensions and drag curves.
#
# **Pay special attention to *position* related parameters:**
# More details on [Positions and Coordinate Systems](https://docs.rocketpy.org/en/latest/user/positions.html)

# %%
Pixel_1_Main = Rocket(
    radius=1.55 * 0.0254,
    mass=5.13,
    inertia=(1.52, 1.52, 0.0078), # OpenRocket Num
    # y = 0.0301x2 - 0.2742x + 1.073
    power_off_drag=0.75,
    # y = -0.2549x2 + 0.4577x + 0.6292
    power_on_drag=0.75,
    center_of_mass_without_motor=112.0 / 100,
    coordinate_system_orientation="nose_to_tail",
)

rail_buttons = Pixel_1_Main.set_rail_buttons(
    upper_button_position=131.0 / 100,
    lower_button_position=187.0 / 100,
    angular_position=180,
)

# %% [markdown]
# To add the motor to our rocket we need only inform what motor we are adding, and inform the position, in meters, of the motor's nozzle exit area relative to the previously defined coordinate system.

# %%
Pixel_1_Main.add_motor(Aerotech_K1103X, position= 191.0 / 100)

# %% [markdown]
# #### Adding Aerodynamic Surfaces

# %% [markdown]
# Now we define the aerodynamic surfaces. They are really straight forward with special attention needed only for the position values. Here is a quick guide:
#
# - The positions given **must** be relative to the same coordinate system as the rockets;
# - Position of the Nosecone refers to the tip of the nose;
# - Position of fins refers to the point belonging to the root chord which is highest in the rocket coordinate system;
# - Position of the tail the point belonging to the tail which is highest in the rocket coordinate system.
#
# See more details in [Positions and Coordinate Systems](https://docs.rocketpy.org/en/latest/user/positions.html)

# %%
nose_cone = Pixel_1_Main.add_nose(length=16.5 * 0.0254, kind="ogive", position=0)

fin_set = Pixel_1_Main.add_trapezoidal_fins(
    n=3,
    root_chord=10 * 0.0254,
    tip_chord=4.5 * 0.0254,
    span=3 * 0.0254,
    position=170.0 / 100,
    cant_angle=31,
)

#tail = Pixel_1_Main.add_tail(
#    top_radius=0.0635, bottom_radius=0.0435, length=0.060, position=-1.194656
#)

# %% [markdown]
# To see all information regarding the rocket we just defined we run:

# %%
Pixel_1_Main.all_info()
# Out:
# Inertia Details
#
# Rocket Mass: 5.130 kg (without motor)
# Rocket Dry Mass: 5.759 kg (with unloaded motor)
# Rocket Loaded Mass: 6.262 kg
# Rocket Structural Mass Ratio: 0.920
# Rocket Inertia (with unloaded motor) 11: 1.718 kg*m2
# Rocket Inertia (with unloaded motor) 22: 1.718 kg*m2
# Rocket Inertia (with unloaded motor) 33: 0.008 kg*m2
# Rocket Inertia (with unloaded motor) 12: 0.000 kg*m2
# Rocket Inertia (with unloaded motor) 13: 0.000 kg*m2
# Rocket Inertia (with unloaded motor) 23: 0.000 kg*m2
#
# Geometrical Parameters
#
# Rocket Maximum Radius: 0.03937 m
# Rocket Frontal Area: 0.004869 m2
#
# Rocket Distances
# Rocket Center of Dry Mass - Center of Mass without Motor: 0.064 m
# Rocket Center of Dry Mass - Nozzle Exit: 0.726 m
# Rocket Center of Dry Mass - Center of Propellant Mass: 0.526 m
# Rocket Center of Mass - Rocket Loaded Center of Mass: 0.042 m
#
#
# Aerodynamics Lift Coefficient Derivatives
#
# Nose Cone Lift Coefficient Derivative: 2.000/rad
# Fins Lift Coefficient Derivative: 7.018/rad
#
# Center of Pressure
#
# Nose Cone Center of Pressure position: 0.195 m
# Fins Center of Pressure position: 1.809 m
#
# Stability
#
# Center of Mass position (time=0): 1.227 m
# Center of Pressure position (time=0): 1.451 m
# Initial Static Margin (mach=0, time=0): 2.853 c
# Final Static Margin (mach=0, time=burn_out): 3.389 c
# Rocket Center of Mass (time=0) - Center of Pressure (mach=0): 0.225 m
#
#
# Rocket Draw
# ----------------------------------------
# Mass Plots
# ----------------------------------------
# Aerodynamics Plots
# ----------------------------------------
# Drag Plots
# --------------------
# Stability Plots
# --------------------
# Thrust-to-Weight Plot
# ----------------------------------------

# %% [markdown]
# #### Adding Parachutes

# %% [markdown]
# Finally, we have parachutes! Calisto will have two parachutes, Drogue and Main. The Drogue parachute will open at apogee while the Main parachute will open at 800m above ground level
#
# For more details see [Adding Parachutes](https://docs.rocketpy.org/en/latest/user/rocket.html#adding-parachutes)

# %%
Main = Pixel_1_Main.add_parachute(
    "Main",
    cd_s=1.86,
    trigger=600,
    sampling_rate=105,
    lag=0,
    noise=(0, 8.3, 0.5),
)

Drogue = Pixel_1_Main.add_parachute(
    "Drogue",
    cd_s=0.123,
    trigger="apogee",
    sampling_rate=105,
    lag=0,
    noise=(0, 8.3, 0.5),
)

# %% [markdown]
# Just be careful if you run this last cell multiple times! If you do so, your rocket will end up with lots of parachutes which activate together, which may cause problems during the flight simulation. We advise you to re-run all cells which define our rocket before running this, preventing unwanted old parachutes. Alternatively, you can run the following lines to remove parachutes.
#
# ```python
# Calisto.parachutes.remove(Drogue)
# Calisto.parachutes.remove(Main)
# ```

# %% [markdown]
# ## Simulating a Flight
#
# Simulating a flight trajectory is as simple as initializing a Flight class object givin the rocket and environnement set up above as inputs. The launch rail inclination and heading are also given here.

# %%
test_flight_Main = Flight(
    rocket=Pixel_1_Main, environment=env, rail_length=2.44, inclination=85, heading=0
)

# %% [markdown]
# ## Analyzing the Results
#
# RocketPy gives you many plots, thats for sure! They are divided into sections to keep them organized. Alternatively, see the Flight class documentation to see how to get plots for specific variables only, instead of all of them at once.

# %%
test_flight_Main.all_info()
# Out:
# Initial Conditions
#
# Initial time: 0.000 s
# Position - x: 0.00 m | y: 0.00 m | z: 692.00 m
# Velocity - Vx: 0.00 m/s | Vy: 0.00 m/s | Vz: 0.00 m/s
# Attitude (quaternions) - e0: 0.000 | e1: -0.000 | e2: 0.044 | e3: 0.999
# Euler Angles - Spin φ : 180.00° | Nutation θ: -5.00° | Precession ψ: 0.00°
# Angular Velocity - ω1: 0.00 rad/s | ω2: 0.00 rad/s | ω3: 0.00 rad/s
# Initial Stability Margin: 2.853 c
#
#
# Surface Wind Conditions
#
# Frontal Surface Wind Speed: 0.00 m/s
# Lateral Surface Wind Speed: 0.00 m/s
#
#
# Launch Rail
#
# Launch Rail Length: 2.44 m
# Launch Rail Inclination: 85.00°
# Launch Rail Heading: 0.00°
#
#
# Rail Departure State
#
# Rail Departure Time: 0.134 s
# Rail Departure Velocity: 28.150 m/s
# Rail Departure Stability Margin: 2.905 c
# Rail Departure Angle of Attack: -0.000°
# Rail Departure Thrust-Weight Ratio: 22.096
# Rail Departure Reynolds Number: 1.438e+05
#
#
# Burn out State
#
# Burn out time: 1.600 s
# Altitude at burn out: 933.323 m (ASL) | 241.323 m (AGL)
# Rocket speed at burn out: 267.560 m/s
# Freestream velocity at burn out: 267.560 m/s
# Mach Number at burn out: 0.795
# Kinetic energy at burn out: 2.074e+05 J
#
#
# Apogee State
#
# Apogee Time: 19.162 s
# Apogee Altitude: 2771.988 m (ASL) | 2079.988 m (AGL)
# Apogee Freestream Speed: 13.422 m/s
# Apogee X position: -3.069 m
# Apogee Y position: 319.230 m
# Apogee latitude: 41.7782648°
# Apogee longitude: -86.5725039°
#
#
# Parachute Events
#
# No Parachute Events Were Triggered.
#
#
# Impact Conditions
#
# Time of impact: 42.277 s
# X impact: -13.428 m
# Y impact: 550.781 m
# Altitude impact: 692.000 m (ASL) | -0.000 m (AGL)
# Latitude: 41.7803480°
# Longitude: -86.5726288°
# Vertical velocity at impact: -147.214 m/s
# Number of parachutes triggered until impact: 0
#
#
# Stability Margin
#
# Initial Stability Margin: 2.853 c at 0.00 s
# Out of Rail Stability Margin: 2.905 c at 0.13 s
# Maximum Stability Margin: 3.539 c at 1.60 s
# Minimum Stability Margin: 2.853 c at 0.00 s
#
#
# Maximum Values
#
# Maximum Speed: 267.573 m/s at 1.59 s
# Maximum Mach Number: 0.795 Mach at 1.60 s
# Maximum Reynolds Number: 1.341e+06 at 1.58 s
# Maximum Dynamic Pressure: 4.006e+04 Pa at 1.59 s
# Maximum Acceleration During Motor Burn: 248.208 m/s² at 0.03 s
# Maximum Gs During Motor Burn: 25.310 g at 0.03 s
# Maximum Acceleration After Motor Burn: 0.000 m/s² at 0.00 s
# Maximum Gs After Motor Burn: 0.000 Gs at 0.00 s
# Maximum Stability Margin: 3.539 c at 1.60 s
# Maximum Upper Rail Button Normal Force: 0.000 N
# Maximum Upper Rail Button Shear Force: 0.000 N
# Maximum Lower Rail Button Normal Force: 0.000 N
# Maximum Lower Rail Button Shear Force: 0.000 N
#
#
# Numerical Integration Settings
#
# Maximum Allowed Flight Time: 600.00 s
# Maximum Allowed Time Step: inf s
# Minimum Allowed Time Step: 0.00e+00 s
# Relative Error Tolerance: 1e-06
# Absolute Error Tolerance: [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 1e-06, 1e-06, 1e-06, 1e-06, 0.001, 0.001, 0.001]
# Allow Event Overshoot: True
# Terminate Simulation on Apogee: False
# Number of Time Steps Used: 23393
# Number of Derivative Functions Evaluation: 46730
# Average Function Evaluations per Time Step: 1.998
#
#
#
# Trajectory 3d Plot
# Trajectory Kinematic Plots
# Angular Position Plots
# Path, Attitude and Lateral Attitude Angle plots
# Trajectory Angular Velocity and Acceleration Plots
# Aerodynamic Forces Plots
# Rail Buttons Forces Plots
# Trajectory Energy Plots
# Trajectory Fluid Mechanics Plots
# Trajectory Stability and Control Plots
# Rocket and Parachute Pressure Plots
# Rocket has no parachutes. No parachute plots available

# %% [markdown]
# Export Flight Trajectory to a .kml file so it can be opened on Google Earth

# %%
test_flight_Main.export_kml(
    file_name="trajectory.kml",
    extrude=True,
    altitude_mode="relative_to_ground",
)
# Out:
# File  trajectory.kml  saved with success!
# /tmp/ipython-input-8717744.py:1: DeprecationWarning: Moved to FlightDataExporter.export_kml() and will be removed in v1.12.0. Use `rocketpy.simulation.flight_data_exporter.FlightDataExporter.export_kml` instead.
#   test_flight.export_kml(

# %% [markdown]
# ## Using Simulation for Design
#
# Here, we go through a couple of examples which make use of RocketPy in cool ways to help us design our rocket.

# %% [markdown]
# ### Apogee as a Function of Mass
#
# This one is a classic one! We always need to know how much our rocket's apogee will change when our payload gets heavier.

# %%
from rocketpy.utilities import apogee_by_mass

apogee_by_mass(flight=test_flight_Main, min_mass=5, max_mass=20, points=10, plot=True)
# Out:
# 'Function from R1 to R1 : (Rocket Mass without motor (kg)) → (Apogee AGL (m))'

# %% [markdown]
# ### Out of Rail Speed as a Function of Mass
#
# Lets make a really important plot. Out of rail speed is the speed our rocket has when it is leaving the launch rail. This is crucial to make sure it can fly safely after leaving the rail. A common rule of thumb is that our rocket's out of rail speed should be 4 times the wind speed so that it does not stall and become unstable.

# %%
from rocketpy.utilities import liftoff_speed_by_mass

liftoff_speed_by_mass(flight=test_flight_Main, min_mass=5, max_mass=20, points=10, plot=True)
# Out:
# 'Function from R1 to R1 : (Rocket Mass without motor (kg)) → (Out of Rail Speed (m/s))'

# %% [markdown]
# ### Dynamic Stability Analysis
#
# Ever wondered how static stability translates into dynamic stability? Different static margins result in different dynamic behavior, which also depends on the rocket's rotational inertial.
#
# Let's make use of RocketPy's helper class called Function to explore how the dynamic stability of Calisto varies if we change the fins span by a certain factor.

# %%
# Helper class
import copy

from rocketpy import Function

# Prepare a copy of the rocket
Pixel_1_Main_Copy = copy.deepcopy(Pixel_1_Main)

# Prepare Environment Class
custom_env = Environment()
custom_env.set_atmospheric_model(type="custom_atmosphere", wind_v=-5)

# Simulate Different Static Margins by Varying Fin Position
simulation_results = []

for factor in [-0.5, -0.2, 0.1, 0.4, 0.7]:
    # Modify rocket fin set by removing previous one and adding new one
    Pixel_1_Main_Copy.aerodynamic_surfaces.pop(-1)

    fin_set = Pixel_1_Main_Copy.add_trapezoidal_fins(
        n=4,
        root_chord=0.120,
        tip_chord=0.040,
        span=0.100,
        position=-1.04956 * factor,
    )
    # Simulate
    print(
        "Simulating Rocket with Static Margin of {:1.3f}->{:1.3f} c".format(
            Pixel_1_Main_Copy.static_margin(0),
            Pixel_1_Main_Copy.static_margin(Pixel_1_Main_Copy.motor.burn_out_time),
        )
    )
    test_flight = Flight(
        rocket=Pixel_1_Main_Copy,
        environment=custom_env,
        rail_length=2.5,
        inclination=85,
        heading=0,
        max_time_step=0.01,
        max_time=5,
        terminate_on_apogee=True,
        verbose=True,
    )
    # Store Results
    static_margin_at_ignition = Pixel_1_Main_Copy.static_margin(0)
    static_margin_at_out_of_rail = Pixel_1_Main_Copy.static_margin(test_flight.out_of_rail_time)
    static_margin_at_steady_state = Pixel_1_Main_Copy.static_margin(test_flight.t_final)
    simulation_results += [
        (
            test_flight.attitude_angle,
            "{:1.2f} c | {:1.2f} c | {:1.2f} c".format(
                static_margin_at_ignition,
                static_margin_at_out_of_rail,
                static_margin_at_steady_state,
            ),
        )
    ]

Function.compare_plots(
    simulation_results,
    lower=0,
    upper=1.5,
    xlabel="Time (s)",
    ylabel="Attitude Angle (deg)",
)
# Out:
# Simulating Rocket with Static Margin of -7.679->-7.502 c
#
# >>> Simulation Completed at Time: 5.0000 s
# Simulating Rocket with Static Margin of -11.085->-10.908 c
#
# >>> Simulation Completed at Time: 4.5154 s
# Simulating Rocket with Static Margin of -14.491->-14.314 c
#
# >>> Simulation Completed at Time: 3.6537 s
# Simulating Rocket with Static Margin of -17.897->-17.720 c
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_474/1032840157.py in <cell line: 0>()
#      32         )
#      33     )
# ---> 34     test_flight = Flight(
#      35         rocket=Pixel_1_Main_Copy,
#      36         environment=custom_env,
#
# /usr/local/lib/python3.12/dist-packages/rocketpy/simulation/flight.py in __init__(self, rocket, environment, rail_length, inclination, heading, initial_solution, terminate_on_apogee, max_time, max_time_step, min_time_step, rtol, atol, time_overshoot, verbose, name, equations_of_motion, ode_solver)
#     618
#     619         # Simulate flight
# --> 620         self.__simulate(verbose)
#     621
#     622         # Initialize prints and plots objects
#
# /usr/local/lib/python3.12/dist-packages/rocketpy/simulation/flight.py in __simulate(self, verbose)
#     797                 while phase.solver.status == "running":
#     798                     # Execute solver step, log solution and function evaluations
# --> 799                     phase.solver.step()
#     800                     self.solution += [[phase.solver.t, *phase.solver.y]]
#     801                     self.function_evaluations.append(phase.solver.nfev)
#
# /usr/local/lib/python3.12/dist-packages/scipy/integrate/_ivp/base.py in step(self)
#     195         else:
#     196             t = self.t
# --> 197             success, message = self._step_impl()
#     198
#     199             if not success:
#
# /usr/local/lib/python3.12/dist-packages/scipy/integrate/_ivp/lsoda.py in _step_impl(self)
#     159         itask = integrator.call_args[2]
#     160         integrator.call_args[2] = 5
# --> 161         solver._y, solver.t = integrator.run(
#     162             solver.f, solver.jac or (lambda: None), solver._y, solver.t,
#     163             self.t_bound, solver.f_params, solver.jac_params)
#
# /usr/local/lib/python3.12/dist-packages/scipy/integrate/_ode.py in run(self, f, jac, y0, t0, t1, f_params, jac_params)
#    1363
#    1364         with LSODA_LOCK:
# -> 1365             y1, t, istate = self.runner(*args)
#    1366
#    1367         self.istate = istate
#
# /usr/local/lib/python3.12/dist-packages/scipy/integrate/_ivp/base.py in fun(t, y)
#     152         def fun(t, y):
#     153             self.nfev += 1
# --> 154             return self.fun_single(t, y)
#     155
#     156         self.fun = fun
#
# /usr/local/lib/python3.12/dist-packages/scipy/integrate/_ivp/base.py in fun_wrapped(t, y)
#      21
#      22     def fun_wrapped(t, y):
# ---> 23         return np.asarray(fun(t, y), dtype=dtype)
#      24
#      25     return fun_wrapped, y0
#
# /usr/local/lib/python3.12/dist-packages/rocketpy/simulation/flight.py in u_dot_generalized(self, t, u, post_processing)
#    1810         inertia_tensor = self.rocket.get_inertia_tensor_at_time(t)
#    1811         ## Inertia tensor time derivative in the body frame
# -> 1812         I_dot = self.rocket.get_inertia_tensor_derivative_at_time(t)
#    1813
#    1814         # Calculate the Inertia tensor relative to CM
#
# /usr/local/lib/python3.12/dist-packages/rocketpy/rocket/rocket.py in get_inertia_tensor_derivative_at_time(self, t)
#     933         I_23_dot = self.I_23.differentiate_complex_step(t)
#     934         I_33_dot = self.I_33.differentiate_complex_step(t)
# --> 935         return Matrix(
#     936             [
#     937                 [I_11_dot, I_12_dot, I_13_dot],
#
# /usr/local/lib/python3.12/dist-packages/rocketpy/mathutils/vector_matrix.py in __init__(self, components)
#     559     __array_ufunc__ = None
#     560
# --> 561     def __init__(self, components):
#     562         """Matrix class constructor.
#     563
#
# KeyboardInterrupt:

# %%
# Helper class
import copy

from rocketpy import Function

# Prepare a copy of the rocket
Pixel_1_Subscale_Copy = copy.deepcopy(Pixel_1_Subscale)

# Prepare Environment Class
custom_env = Environment()
custom_env.set_atmospheric_model(type="custom_atmosphere", wind_v=-5)

# Simulate Different Static Margins by Varying Fin Position
simulation_results = []

for factor in [-0.5, -0.2, 0.1, 0.4, 0.7]:
    # Modify rocket fin set by removing previous one and adding new one
    Pixel_1_Subscale_Copy.aerodynamic_surfaces.pop(-1)

    fin_set = Pixel_1_Subscale_Copy.add_trapezoidal_fins(
        n=4,
        root_chord=0.120,
        tip_chord=0.040,
        span=0.100,
        position=-1.04956 * factor,
    )
    # Simulate
    print(
        "Simulating Rocket with Static Margin of {:1.3f}->{:1.3f} c".format(
            Pixel_1_Subscale_Copy.static_margin(0),
            Pixel_1_Subscale_Copy.static_margin(Pixel_1_Subscale_Copy.motor.burn_out_time),
        )
    )
    test_flight = Flight(
        rocket=Pixel_1_Subscale_Copy,
        environment=custom_env,
        rail_length=5.2,
        inclination=90,
        heading=0,
        max_time_step=0.01,
        max_time=5,
        terminate_on_apogee=True,
        verbose=True,
    )
    # Store Results
    static_margin_at_ignition = Pixel_1_Subscale_Copy.static_margin(0)
    static_margin_at_out_of_rail = Pixel_1_Subscale_Copy.static_margin(test_flight.out_of_rail_time)
    static_margin_at_steady_state = Pixel_1_Subscale_Copy.static_margin(test_flight.t_final)
    simulation_results += [
        (
            test_flight.attitude_angle,
            "{:1.2f} c | {:1.2f} c | {:1.2f} c".format(
                static_margin_at_ignition,
                static_margin_at_out_of_rail,
                static_margin_at_steady_state,
            ),
        )
    ]

Function.compare_plots(
    simulation_results,
    lower=0,
    upper=1.5,
    xlabel="Time (s)",
    ylabel="Attitude Angle (deg)",
)

# %% [markdown]
# ### Characteristic Frequency Calculation
#
# Here we analyse the characteristic frequency of oscillation of our rocket just as it leaves the launch rail. Note that when we ran test_flight.all_info(), one of the plots already showed us the frequency spectrum of our flight. Here, however, we have more control of what we are plotting.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Simulate first 5 seconds of Flight
flight = Flight(
    rocket=Pixel_1_Main,
    environment=env,
    rail_length=5.2,
    inclination=90,
    heading=0,
    max_time_step=0.01,
    max_time=5,
)

# Perform a Fourier Analysis
Fs = 100.0
# sampling rate
Ts = 1.0 / Fs
# sampling interval
t = np.arange(1, 400, Ts)  # time vector
ff = 5
# frequency of the signal
y = flight.attitude_angle(t) - np.mean(flight.attitude_angle(t))
n = len(y)  # length of the signal
k = np.arange(n)
T = n / Fs
frq = k / T  # two sides frequency range
frq = frq[range(n // 2)]  # one side frequency range
Y = np.fft.fft(y) / n  # fft computing and normalization
Y = Y[range(n // 2)]

# Create the plot
fig, ax = plt.subplots(2, 1)
ax[0].plot(t, y)
ax[0].set_xlabel("Time")
ax[0].set_ylabel("Signal")
ax[0].set_xlim((0, 5))
ax[0].grid()
ax[1].plot(frq, abs(Y), "r")  # plotting the spectrum
ax[1].set_xlabel("Freq (Hz)")
ax[1].set_ylabel("|Y(freq)|")
ax[1].set_xlim((0, 5))
ax[1].grid()
plt.subplots_adjust(hspace=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Simulate first 5 seconds of Flight
flight = Flight(
    rocket=Pixel_1_Subscale,
    environment=env,
    rail_length=5.2,
    inclination=90,
    heading=0,
    max_time_step=0.01,
    max_time=5,
)

# Perform a Fourier Analysis
Fs = 100.0
# sampling rate
Ts = 1.0 / Fs
# sampling interval
t = np.arange(1, 400, Ts)  # time vector
ff = 5
# frequency of the signal
y = flight.attitude_angle(t) - np.mean(flight.attitude_angle(t))
n = len(y)  # length of the signal
k = np.arange(n)
T = n / Fs
frq = k / T  # two sides frequency range
frq = frq[range(n // 2)]  # one side frequency range
Y = np.fft.fft(y) / n  # fft computing and normalization
Y = Y[range(n // 2)]

# Create the plot
fig, ax = plt.subplots(2, 1)
ax[0].plot(t, y)
ax[0].set_xlabel("Time")
ax[0].set_ylabel("Signal")
ax[0].set_xlim((0, 5))
ax[0].grid()
ax[1].plot(frq, abs(Y), "r")  # plotting the spectrum
ax[1].set_xlabel("Freq (Hz)")
ax[1].set_ylabel("|Y(freq)|")
ax[1].set_xlim((0, 5))
ax[1].grid()
plt.subplots_adjust(hspace=0.5)
plt.show()
